# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
file = os.path.join("nfl.csv")

# %%
df = pd.read_csv(file)
df =

# %%
player = df["Player"]
age = df["Age"]

# %%
df
# Out:
#     Rk                    Player   Tm  Age Pos   G  GS   QBrec  Cmp▼  Att  \
# 0    1  Patrick Mahomes\MahoPa00  KAN   25  QB  12  12  11-1-0   316  463
# 1    2       Jared Goff\GoffJa00  LAR   26  QB  12  12   8-4-0   308  450
# 2    3        Tom Brady\BradTo00  TAM   43  QB  12  12   7-5-0   307  474
# 3    4   Russell Wilson\WilsRu00  SEA   32  QB  12  12   8-4-0   305  436
# 4    5        Matt Ryan\RyanMa00  ATL   35  QB  12  12   4-8-0   296  466
# ..  ..                       ...  ...  ...  ..  ..  ..     ...   ...  ...
# 87  88     Russell Gage\GageRu00  ATL   24  wr  12   4     NaN     0    1
# 88  89      Chris Jones\JoneCh02  DAL   31   p   8   0     NaN     0    1
# 89  90       Brett Kern\KernBr20  TEN   34   p   9   0     NaN     0    1
# 90  91       D.J. Moore\MoorD.00  CAR   23  WR  12  12     NaN     0    1
# 91  92      Zach Pascal\PascZa00  IND   26  WR  12  11     NaN     0    1
#
#     ...    Y/G   Rate   QBR  Sk  Yds.1  NY/A  ANY/A  Sk%  4QC  GWD
# ...
